# %%
import numpy as np
import pandas as pd
import rispy as rs
import os
from fuzzywuzzy import fuzz
from pandas_dedupe import dedupe_dataframe
import ast

# %%
def find_partitions(df, match_func, max_size=None, block_by=None):
    '''
    Recursive algorithm for finding duplicates in a DataFrame. 
    Currently not used, took incredibly long
    '''

    # If block_by is provided, then we apply the algorithm to each block and
    # stitch the results back together
    if block_by is not None:
        blocks = df.groupby(block_by).apply(lambda g: find_partitions(
            df=g,
            match_func=match_func,
            max_size=max_size
        ))

        keys = blocks.index.unique(block_by)
        for a, b in zip(keys[:-1], keys[1:]):
            blocks.loc[b, :] += blocks.loc[a].iloc[-1] + 1

        return blocks.reset_index(block_by, drop=True)

    def get_record_index(r):
        return r[df.index.name or 'index']

    # Records are easier to work with than a DataFrame
    records = df.to_records()

    # This is where we store each partition
    partitions = []

    def find_partition(at=0, partition=None, indexes=None):

        r1 = records[at]

        if partition is None:
            partition = {get_record_index(r1)}
            indexes = [at]

        # Stop if enough duplicates have been found
        if max_size is not None and len(partition) == max_size:
            return partition, indexes

        for i, r2 in enumerate(records):

            if get_record_index(r2) in partition or i == at:
                continue

            if match_func(r1, r2):
                partition.add(get_record_index(r2))
                indexes.append(i)
                find_partition(at=i, partition=partition, indexes=indexes)

        return partition, indexes

    while len(records) > 0:
        partition, indexes = find_partition()
        partitions.append(partition)
        records = np.delete(records, indexes)

    return pd.Series({
        idx: partition_id
        for partition_id, idxs in enumerate(partitions)
        for idx in idxs
    })

# %%
def default_csv_read(filepath, file):
    return pd.read_csv(f'{filepath}/{file}',
            header=0,
            delimiter='  - ',
            names=['label','content'],
            engine='python')

def read_ris(filepath):
    with open(filepath, 'r') as risfile:
        return rs.load(risfile)

def write_ris(entries, filepath):
    with open(filepath, 'w') as risfile:
        rs.dump(entries, risfile)

def get_titles(risfiles):
    titles_list = []
    for risfile in risfiles:
        titles = []
        for entry in risfile:
            titles += [entry['title']]
        titles_list += [titles]

    return titles_list

def compare_lists(list_of_lists):
    '''
    Should be able to compare n>0 lists and find dupes
    TODO: Integrate fuzzy search instead of 'in seen' should be 'if fuzzy enough add to set
        Possibly incompatible with the use of sets
    '''
    seen = set()
    repeated = set()
    
    for l in list_of_lists:
        for i in set(l):
            if i in seen:
                repeated.add(i)
            else:
                seen.add(i)
    return repeated

def matching(list1, list2):
    no_matching = []
    matching = []
    m_score = 0
    cutoff = 60
    for item1 in list1:    
        for item2 in list2:        
            m_score = fuzz.ratio(item1.lower(), item2.lower())
            if m_score > cutoff:
                matching.append(item1)
        if m_score < cutoff and not(item1 in matching):
            no_matching.append(item1)
    return matching, no_matching

def get_dupes(path):
    risfiles = []
    filenames = os.listdir(path)
    for name in filenames:
        risfiles += [read_ris(f'{path}/{name}')]

    # Find duplicate titles    
    tls = get_titles(risfiles)

    # dupes = list(compare_lists(tls))
    dupes = matching(tls[0], tls[1])[0]

    print(f'{len(dupes)} duplicates found in {filenames}: \n{dupes}')

    # Get the entries in the ris files corresponding to the duplicate titles
    fe = []
    seen = set()
    for title in dupes:
        for file in risfiles:
            for entry in file:
                if entry['title'] == title and title not in seen:
                    fe += [entry]
                    seen.add(title)

    return fe, risfiles

def dedupe_naive(file, keys=['doi','title']):
    '''Deduplicate a large ris file using naive string matching (non-fuzzy)'''
    risfile = read_ris(file)
    df = pd.DataFrame.from_dict(risfile)

    def remove_dupes(df, subset):
        for sub in subset:
            # df=df[(~df.duplicated(subset=sub)) | (df[sub].isnull())]
            df = df[~df[sub].str.lower().duplicated() | (df[sub].isnull())]
        return df

    dfd = remove_dupes(df, keys)

    print(f'before:{df.shape}, after: {dfd.shape}')
    
    return dfd

def merge_ris(path, outfilename, overwrite=False):
    files = os.listdir(path)

    if not os.path.exists(outfilename) or overwrite:
        with open(outfilename, 'w') as outfile:
            for fname in files:
                fname = f'{path}/{fname}'
                with open(fname) as infile:
                    for line in infile:
                        outfile.write(line)
        
        # Remove special characters that mess up dedupe after
        input = outfilename
        output = outfilename+'_.ris'
        with open(input, 'r') as infile, \
            open(output, 'w') as outfile:
            data = infile.read()
            data = data.replace("﻿", "")
            outfile.write(data)
        os.remove(outfilename)
        os.rename(output, output[:-5])
    else:
        print('merge file already exists, change name or set overwrite function parameter to True')
    return None

def dedupe_ml(file, keys=['doi','title','authors']):
    '''
    machine learning dedupe
    clusters of equal entries are given the same cluster id
    ''' 
    # read file
    risfile = read_ris(file)
    df = pd.DataFrame.from_dict(risfile)
    # find dupes and assign cluster ids to them
    dfd = dedupe_dataframe(df, keys)

    # dedupe using found cluster ids by uniquefying
    # NOTE: 1. The below commented doesn't work because dedupe_dataframe removes list structure from authors, so the subsequent write to ris fails using write-ris_dedupe
    # a = dfd[~dfd['cluster id'].duplicated()]
    # print(f'deduped from {df.shape} to {a.shape}')

    # Get original dataframe entries with good .ris format that correspond to a unique cluster id
    # NOTE: 1.1 Do manually instead
    temp = []
    seen = set()
    for index, row in df.iterrows():
        cluster_id = dfd.iloc[index]['cluster id']
        if cluster_id not in seen:
            temp.append(row)
            seen.add(cluster_id)
    a = pd.DataFrame(temp)
    print(f'deduped from {df.shape} to {a.shape}')  

    dl = [{k:v for k,v in m.items() if pd.notnull(v) and v != 'nan'} for m in a.to_dict('records')]

    def destring(dl):
        s = set(['authors', 'keywords', 'notes', 'first_authors', 'secondary_authors'])
        
        for i in dl:
            for k,v in i.items():
                if k in s:
                    i[k] = ast.literal_eval(v)
                # else:
                    # i[k] = v

        return dl

    dl = destring(dl)

    return dl, a, df, risfile

# %%
'''
Right now only works for 2 ris files
Provides a list of duplicates from a collection of .ris files
Duplicates are identified by title only, based on a fuzzy string search 
Using the fuzzywuzzy package with an equality cutoff ratio of 60/100
'''
name = '220526'
datapath = f'../data/{name}'

# %%
dupes, risfiles = get_dupes(path=f'{datapath}/core')
merge_ris(path=f'{datapath}/core', outfilename=f'{datapath}/core.ris', overwrite=True)
# Out:
# 8 duplicates found in ['wos_core_10.ris', 'scopus_core_17.ris']:
# ['Combating Climate Change Through a Duty to Divest', "Tom Steyer on clean energy: It's where the big money is going", 'RENEWABLE ENERGY GOVERNANCE: GLOBAL EXPERIENCE AND SIBERIA', 'Mapping the environmental field: Networks of foundations, ENGOs and think tanks', 'Regenerative, semiclosed systems: A priority for twenty-first-century agriculture', 'Could 79 People Solarize the U.S. Electric Grid?', 'A New Tool to Evaluate, Improve, and Sustain Marine Protected Area Financing Built on a Comprehensive Review of Finance Sources and Instruments', 'Strategic philanthropy in the post-Cap-and-Trade years: Reviewing US climate and energy foundation funding']
# 0

# %%
merge_ris(path=f'{datapath}/merge', outfilename=f'{datapath}/{name}.ris', overwrite=True)
# Out:
# 0

# %%
dl, a, df, risfile = dedupe_ml(f'{datapath}/{name}.ris')

f = write_ris(dl, f'../asreview/input/{name}_dedupe.ris')
# Out:
# Importing data ...
# /tmp/ipykernel_269/1739921731.py:134: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfd = dedupe_dataframe(df, keys)
# doi : 10.1053/j.ajkd.2014.09.031
# title : funding renal replacement therapy in southeast asia: building public-private partnerships in singapore, malaysia, thailand, and indonesia
# authors : None
#
# doi : 10.1053/j.ajkd.2014.09.031
# title : funding renal replacement therapy in southeast asia: building public-private partnerships in singapore, malaysia, thailand, and indonesia
# authors : morad, z, choong, hl, tungsanga, k, suhardjono
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# Starting active labeling...
# doi : 10.1016/j.orgdyn.2015.02.003
# title : the sustainable effectiveness model: moving corporations beyond the philanthropy paradigm.
# authors : None
#
# doi : 10.1016/j.orgdyn.2015.02.003
# title : the sustainable effectiveness model: moving corporations beyond the philanthropy paradigm
# authors : lawler, ee, conger, ja
#
# 1/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.4324/9781315613789
# title : the ashgate research companion to world methodism
# authors : gibson, w., forsaith, p., wellings, m.
#
# doi : None
# title : the ashgate research companion to world methodism
# authors : gibson, w., forsaith, p., wellings, m.
#
# 2/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : to make a difference: the founding of the crohns and colitis foundation of america.
# authors : rosenthal, s.
#
# doi : None
# title : to make a difference: the founding of the crohns and colitis foundation of america
# authors : rosenthal, s
#
# 3/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g.
#
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g
#
# 4/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1827)
# authors : gursoy, c.
#
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1828)
# authors : gursoy, c
#
# 5/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : eco-responsible cities and the global ocean: geostrategic shifts and the sustainability trilemma
# authors : mega, vp
#
# doi : 10.1007/978-3-319-93680-2
# title : eco-responsible cities and the global ocean
# authors : mega, vp
#
# 6/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : tracks and shadows: field biology as art
# authors : greene, hw
#
# doi : 10.1525/9780520956735
# title : tracks and shadows
# authors : greene, hw
#
# 7/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.17059/2013-3-11
# title : development of protected area system of the komi republic
# authors : tikhonova, t.v.
#
# doi : None
# title : development of protected area system of the komi republic
# authors : tikhonova, tv
#
# 8/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : how public is private philanthropy separating reality from myth (philanthropy roundtable, 2d ed. 2012)(with j. tyler)
# authors : brody, e
#
# doi : None
# title : how public is private philanthropy: separating reality from myth
# authors : brody, e, tyler, je
#
# 9/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the self-management and transition to adulthood program unc starx
# authors : ferris, m.e., ferris, m.t., viall, c., stewart, h.d., fenton, n., haberman, c., iglesia, e.a., hancock, l.e., harward, d.h., gilleskie, d., oneill, imperial, r., ko, z., benton, m.h., doan, m., bickford, k., detwiler, r., andreoni, k., mahan, j.d., smith, z., gibson, k., hooper, s.
#
# doi : None
# title : the self-management and transition-to-adulthood program at the university of north carolina: lessons learned (and still learning)
# authors : ferris, m.e., ferris, m.t., viall, c., stewart, h.d., fenton, n., haberman, c., iglesia, e.g.a., hancock, l.e., harward, d.h., gilleskie, d., oneill, j., imperial, r., ko, z., benton, m.h., doan, m., bickford, k., detwiler, r., andreoni, k., mahan, j.d., smith, z., hooper, s., gibson, k.l.
#
# 10/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# doi : None
# title : corporate social responsibility and leadership
# authors : duns, s.
#
# 10/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1163/18765149-12341305
# title : mindfully sharing capital in modern china
# authors : lu, s., rios, j., huang, c.-c.
#
# doi : 10.1163/18765149-12341305
# title : mindfully sharing capital in modern china culture of giving and influence of chinese philosophy
# authors : lu, s, rios, j, huang, cc
#
# 10/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the undp spends 2m. on grass-roots income-generation in uganda.
# authors : None
#
# doi : 10.3390/ph15020153
# title : exploring toxins for hunting sars-cov-2 main protease inhibitors: molecular docking, molecular dynamics, pharmacokinetic properties, and reactome study
# authors : ibrahim, maa, abdelrahman, ahm, jaragh-alhadad, la, atia, mam, alzahrani, or, ahmed, mn, moustafa, ms, soliman, mes, shawky, am, pare, pw, hegazy, mef, sidhom, pa
#
# 11/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : nela recognizes outstanding contributions
# authors : None
#
# doi : 10.1080/13511610.2013.850019
# title : transition in practice and action in research. a french case study in piloting eco-innovations
# authors : audet, r, guyonnaud, mf
#
# 11/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1371/journal.pone.0168867
# title : sustainable development in surgery: the health, poverty, and equity impacts of charitable surgery in uganda
# authors : shrime, m.g., sekidde, s., linden, a., cohen, j.l., weinstein, m.c., salomon, j.a.
#
# doi : 10.1002/9781119199137.ch3
# title : sustainable investment strategies
# authors : None
#
# 11/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# doi : 10.1080/14683857.2015.1091181
# title : corporate social responsibility in local context: international capital, charitable giving and the politics of education in turkey
# authors : knudsen, s.
#
# 11/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the political economy of the low-carbon transition: pathways beyond techno-optimism
# authors : kirby, p, omahony, t
#
# doi : 10.1007/978-3-319-62554-6
# title : the political economy of the low-carbon transition
# authors : techno-optimism, pb, kirby, p, omahony, t
#
# 11/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : 17chapter
# authors : tan, cc
#
# doi : 10.1016/j.jaac.2021.03.005
# title : editors note and special communication: research priorities in child and adolescent mental health emerging from the covid-19 pandemic
# authors : novins, d.k., stoddard, j., althoff, r.r., charach, a., cortese, s., cullen, k.r., frazier, j.a., glatt, s.j., henderson, s.w., herringa, r.j., hulvershorn, l., kieling, c., mcbride, a.b., mccauley, e., middeldorp, c.m., reiersen, a.m., rockhill, c.m., sagot, a.j., scahill, l., simonoff, e., stewart, s.e., szigethy, e., taylor, j.h., white, t., zima, b.t.
#
# 12/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : e-waste not
# authors : oconnell, k.a.
#
# doi : 10.1080/14759756.2021.1909207
# title : y sin embargo te quiero (and yet, i love you): an ethnographic study of economic policy and colonial hegemonies encoded in the recommodification of used garments
# authors : oconnell, mj
#
# 12/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# doi : 10.1002/bse.630
# title : corporate social responsibility in china: an analysis of domestic and foreign retailers sustainability dimensions
# authors : kolk, a., hong, p., van dolen, w.
#
# 12/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1163/18765149-12341340
# title : investigation into funding strategies of social enterprises
# authors : shengfen, z.
#
# doi : 10.1163/18765149-12341340
# title : investigation into funding strategies of social enterprises
# authors : zheng, sf
#
# 12/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1080/13504509.2019.1706661
# title : analysis of the relationships between corporate social responsibility and corporate sustainability: empirical study of co-operativism in ecuador
# authors : loor alcivar, m.i., gonzalez santa cruz, f., moreira mero, n.y., hidalgo fernandez, a.
#
# doi : 10.1080/13504509.2019.1706661
# title : analysis of the relationships between corporate social responsibility and corporate sustainability: empirical study of co-operativism in ecuador
# authors : alcivar, mil, cruz, fgs, mero, nym, fernandez, ah
#
# 13/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1057/9780230611269
# title : nongovernmental organizations in international society
# authors : recognition, s over
#
# doi : None
# title : nongovernmental organizations in international society: struggles over recognition
# authors : heins, v
#
# 14/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the continuing food crisis
# authors : lag, gpr
#
# doi : None
# title : the continuing food crisis: global policy reforms lag
# authors : wise, ta, murphy, s
#
# 14/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : quantified: redefining conservation for the next economy
# authors : whitworth, j
#
# doi : 10.5822/978-1-61091-615-8
# title : quantified
# authors : whitw, joe
#
# 14/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.5325/pennhistory.88.4.0548
# title : architecture and identity in a model community and a modern cultural landscape
# authors : mcmahon, j.d., jr.
#
# doi : 10.5325/pennhistory.88.4.0548
# title : milton hersheys world architecture and identity in a model community and a modern cultural landscape
# authors : mcmahon, jd
#
# 15/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1007/978-3-319-66556-6
# title : impact investing
# authors : spiess-knafl, w, scheck, b
#
# doi : None
# title : impact investing: instruments, mechanisms and actors
# authors : spiess-knafl, w, scheck, b
#
# 16/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : capital and the common good: how innovative finance is tackling the worlds most urgent problems
# authors : keohane, gl
#
# doi : 10.7312/keoh17802
# title : capital and the common good
# authors : keohane, gl
#
# 17/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1007/978-3-030-30413-3_1
# title : introduction to social sustainability
# authors : nilipour, a.
#
# doi : 10.4324/9780203106082-29
# title : introduction
# authors : None
#
# 18/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# doi : 10.1123/jsm.2017-0227
# title : corporate social responsibility in professional team sports organizations: an integrative review
# authors : walzel, s, robertson, j, anagnostopoulos, c
#
# 18/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.31838/jcr.07.11.08
# title : sustainable corporate social responsibility practices of business establishments in region 2, philippines
# authors : pascua, d.s.
#
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# 18/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# Finished labeling
# /home/fdm/software/miniconda3/envs/cliff/lib/python3.9/site-packages/rlr/crossvalidation.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   matthews_cc = ((true_dupes * true_distinct
# Clustering...
# # duplicate sets 3239
# deduped from (4359, 33) to (3239, 33)

# %% [markdown]
# # Experiments

# %%
# naive dedupe
# filepath = '../asreview/input/220420.ris'
# df = dedupe(filepath)

# https://stackoverflow.com/questions/26033301/make-pandas-dataframe-to-a-dict-and-dropna
# a=[ v.dropna().to_dict() for k,v in dfd.iterrows() ]
# write_ris(a,'test.ris')

# %%
# files = ['1-20scopus.ris', '1-20savedrecs.ris']
# filepath = '../data/220420'

# dfs = []
# for file in files:
#     risfile = read_ris(f'{filepath}/{file}')
#     dfs += [pd.DataFrame.from_dict(risfile)]
# df = pd.concat(dfs,ignore_index=True)
# def same_title(t1, t2):
#     return fuzz.ratio(t1['title'].lower(), t2['title'].lower()) > 75
    
# df['real_id'] = find_partitions(
#     df=df,
#     match_func=same_title
# )

# df[df.duplicated(subset='real_id')]
