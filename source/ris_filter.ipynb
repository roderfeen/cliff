# %%
import numpy as np
import pandas as pd
import rispy as rs
import os
from fuzzywuzzy import fuzz
from pandas_dedupe import dedupe_dataframe
import ast

# %%
def find_partitions(df, match_func, max_size=None, block_by=None):
    '''
    Recursive algorithm for finding duplicates in a DataFrame. 
    Currently not used, took incredibly long
    '''

    # If block_by is provided, then we apply the algorithm to each block and
    # stitch the results back together
    if block_by is not None:
        blocks = df.groupby(block_by).apply(lambda g: find_partitions(
            df=g,
            match_func=match_func,
            max_size=max_size
        ))

        keys = blocks.index.unique(block_by)
        for a, b in zip(keys[:-1], keys[1:]):
            blocks.loc[b, :] += blocks.loc[a].iloc[-1] + 1

        return blocks.reset_index(block_by, drop=True)

    def get_record_index(r):
        return r[df.index.name or 'index']

    # Records are easier to work with than a DataFrame
    records = df.to_records()

    # This is where we store each partition
    partitions = []

    def find_partition(at=0, partition=None, indexes=None):

        r1 = records[at]

        if partition is None:
            partition = {get_record_index(r1)}
            indexes = [at]

        # Stop if enough duplicates have been found
        if max_size is not None and len(partition) == max_size:
            return partition, indexes

        for i, r2 in enumerate(records):

            if get_record_index(r2) in partition or i == at:
                continue

            if match_func(r1, r2):
                partition.add(get_record_index(r2))
                indexes.append(i)
                find_partition(at=i, partition=partition, indexes=indexes)

        return partition, indexes

    while len(records) > 0:
        partition, indexes = find_partition()
        partitions.append(partition)
        records = np.delete(records, indexes)

    return pd.Series({
        idx: partition_id
        for partition_id, idxs in enumerate(partitions)
        for idx in idxs
    })

# %%
def default_csv_read(filepath, file):
    return pd.read_csv(f'{filepath}/{file}',
            header=0,
            delimiter='  - ',
            names=['label','content'],
            engine='python')

def read_ris(filepath):
    with open(filepath, 'r') as risfile:
        return rs.load(risfile)

def write_ris(entries, filepath):
    with open(filepath, 'w') as risfile:
        rs.dump(entries, risfile)

def get_titles(risfiles):
    titles_list = []
    for risfile in risfiles:
        titles = []
        for entry in risfile:
            titles += [entry['title']]
        titles_list += [titles]

    return titles_list

def compare_lists(list_of_lists):
    '''
    Should be able to compare n>0 lists and find dupes
    TODO: Integrate fuzzy search instead of 'in seen' should be 'if fuzzy enough add to set
        Possibly incompatible with the use of sets
    '''
    seen = set()
    repeated = set()
    
    for l in list_of_lists:
        for i in set(l):
            if i in seen:
                repeated.add(i)
            else:
                seen.add(i)
    return repeated

def matching(list1, list2):
    no_matching = []
    matching = []
    m_score = 0
    cutoff = 60
    for item1 in list1:    
        for item2 in list2:        
            m_score = fuzz.ratio(item1.lower(), item2.lower())
            if m_score > cutoff:
                matching.append(item1)
        if m_score < cutoff and not(item1 in matching):
            no_matching.append(item1)
    return matching, no_matching

def get_dupes(path):
    risfiles = []
    filenames = os.listdir(path)
    for name in filenames:
        risfiles += [read_ris(f'{path}/{name}')]

    # Find duplicate titles    
    tls = get_titles(risfiles)

    # dupes = list(compare_lists(tls))
    dupes = matching(tls[0], tls[1])[0]

    print(f'{len(dupes)} duplicates found in {filenames}: \n{dupes}')

    # Get the entries in the ris files corresponding to the duplicate titles
    fe = []
    seen = set()
    for title in dupes:
        for file in risfiles:
            for entry in file:
                if entry['title'] == title and title not in seen:
                    fe += [entry]
                    seen.add(title)

    return fe, risfiles

def dedupe_naive(file, keys=['doi','title']):
    '''Deduplicate a large ris file using naive string matching (non-fuzzy)'''
    risfile = read_ris(file)
    df = pd.DataFrame.from_dict(risfile)

    def remove_dupes(df, subset):
        for sub in subset:
            # df=df[(~df.duplicated(subset=sub)) | (df[sub].isnull())]
            df = df[~df[sub].str.lower().duplicated() | (df[sub].isnull())]
        return df

    dfd = remove_dupes(df, keys)

    print(f'before:{df.shape}, after: {dfd.shape}')
    
    return dfd

def merge_ris(path, outfilename, overwrite=False):
    files = os.listdir(path)

    if not os.path.exists(outfilename) or overwrite:
        with open(outfilename, 'w') as outfile:
            for fname in files:
                fname = f'{path}/{fname}'
                with open(fname) as infile:
                    for line in infile:
                        outfile.write(line)
        
        # Remove special characters that mess up dedupe after
        input = outfilename
        output = outfilename+'_.ris'
        with open(input, 'r') as infile, \
            open(output, 'w') as outfile:
            data = infile.read()
            data = data.replace("﻿", "")
            outfile.write(data)
        os.remove(outfilename)
        os.rename(output, output[:-5])
    else:
        print('merge file already exists, change name or set overwrite function parameter to True')
    return None

def dedupe_ml(file, keys=['doi','title','authors']):
    '''
    machine learning dedupe
    clusters of equal entries are given the same cluster id
    ''' 
    # read file
    risfile = read_ris(file)
    df = pd.DataFrame.from_dict(risfile)
    # find dupes and assign cluster ids to them
    dfd = dedupe_dataframe(df, keys)

    # dedupe using found cluster ids by uniquefying
    # NOTE: 1. The below commented doesn't work because dedupe_dataframe removes list structure from authors, so the subsequent write to ris fails using write-ris_dedupe
    # a = dfd[~dfd['cluster id'].duplicated()]
    # print(f'deduped from {df.shape} to {a.shape}')

    # Get original dataframe entries with good .ris format that correspond to a unique cluster id
    # NOTE: 1.1 Do manually instead
    temp = []
    seen = set()
    for index, row in df.iterrows():
        cluster_id = dfd.iloc[index]['cluster id']
        if cluster_id not in seen:
            temp.append(row)
            seen.add(cluster_id)
    a = pd.DataFrame(temp)
    print(f'deduped from {df.shape} to {a.shape}')  

    dl = [{k:v for k,v in m.items() if pd.notnull(v) and v != 'nan'} for m in a.to_dict('records')]

    def destring(dl):
        s = set(['authors', 'keywords', 'notes', 'first_authors', 'secondary_authors'])
        
        for i in dl:
            for k,v in i.items():
                if k in s:
                    i[k] = ast.literal_eval(v)
                # else:
                    # i[k] = v

        return dl

    dl = destring(dl)

    return dl, a, df, risfile

# %%
'''
Right now only works for 2 ris files
Provides a list of duplicates from a collection of .ris files
Duplicates are identified by title only, based on a fuzzy string search 
Using the fuzzywuzzy package with an equality cutoff ratio of 60/100
'''
name = '220526'
datapath = f'../data/{name}'

# %%
# dupes, risfiles = get_dupes(path=f'{datapath}/core')
# merge_ris(path=f'{datapath}/core', outfilename=f'{datapath}/core.ris', overwrite=False)

# %%
# merge_ris(path=f'{datapath}/merge', outfilename=f'{datapath}/{name}.ris', overwrite=False)

# %%
dl, a, df, risfile = dedupe_ml(f'{datapath}/{name}.ris')

f = write_ris(dl, f'../asreview/input/{name}_dedupe.ris')
# Out:
# Importing data ...
# /tmp/ipykernel_1648/3889494116.py:134: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfd = dedupe_dataframe(df, keys)
# doi : 10.1159/000024641
# title : uk charitable organisations concerned with the effects of carbon monoxide poisoning
# authors : None
#
# doi : None
# title : uk charitable organisations concerned with the effects of carbon monoxide poisoning
# authors : anonymous
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# Starting active labeling...
# doi : 10.4324/9781315613789
# title : the ashgate research companion to world methodism
# authors : gibson, w., forsaith, p., wellings, m.
#
# doi : None
# title : the ashgate research companion to world methodism
# authors : gibson, w., forsaith, p., wellings, m.
#
# 1/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : to make a difference: the founding of the crohns and colitis foundation of america.
# authors : rosenthal, s.
#
# doi : None
# title : to make a difference: the founding of the crohns and colitis foundation of america
# authors : rosenthal, s
#
# 2/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g.
#
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g
#
# 3/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1827)
# authors : gursoy, c.
#
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1828)
# authors : gursoy, c
#
# 3/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g.
#
# doi : None
# title : the enterprise in the society: corporate social engagement by sanlam, 1918-1980
# authors : verhoef, g
#
# 3/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1827)
# authors : gursoy, c.
#
# doi : None
# title : same and different: cash waqf records of the foundation accounting court (1491-1828)
# authors : gursoy, c
#
# 4/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.15390/eb.2016.6137
# title : reforming higher education finance in turkey: the alumni-crowdfunded student debt fund a-csdf model
# authors : son-turan, s.
#
# doi : None
# title : reforming higher education finance in turkey: the alumni - crowdfunded student debt fund a-csdf model
# authors : son-turan, s
#
# 5/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : valuing environment-the instrument for democratic and efficient decision making at regional level
# authors : kluvankova, t., spacilova, r.
#
# doi : None
# title : valuing environment - the instrument for democratic and efficient decision making at regional level
# authors : kluvankova, t, spacilova, r
#
# 6/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1098/rsfs.2015.0029
# title : does the world need a global project on artificial photosynthesis
# authors : faunce, t.
#
# doi : 10.1098/rsfs.2015.0029
# title : does the world need a global project on artificial photosynthesis introduction
# authors : faunce, t
#
# 7/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1016/s0305-9006(98)00028-2
# title : cities, regions and privatised utilities
# authors : marvin, s., graham, s., guy, s.
#
# doi : None
# title : cities, regions and privatised utilities - introduction
# authors : marvin, s, graham, s, guy, s
#
# 8/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.4324/9780203111307
# title : the business case for sustainable finance: beyond public relations, ethics and philanthropy
# authors : cherneva, i.
#
# doi : 10.4324/9780203111307
# title : the business case for sustainable finance
# authors : cherneva, i.
#
# 9/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.3390/su131810319
# title : the framing of sustainable finance in charitable foundationsfindings from a qualitative study
# authors : wiener, b.
#
# doi : 10.3390/su131810319
# title : the framing of sustainable finance in charitable foundations-findings from a qualitative study
# authors : wiener, b
#
# 10/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : the self-management and transition to adulthood program unc starx
# authors : ferris, m.e., ferris, m.t., viall, c., stewart, h.d., fenton, n., haberman, c., iglesia, e.a., hancock, l.e., harward, d.h., gilleskie, d., oneill, imperial, r., ko, z., benton, m.h., doan, m., bickford, k., detwiler, r., andreoni, k., mahan, j.d., smith, z., gibson, k., hooper, s.
#
# doi : None
# title : the self-management and transition-to-adulthood program at the university of north carolina: lessons learned (and still learning)
# authors : ferris, m.e., ferris, m.t., viall, c., stewart, h.d., fenton, n., haberman, c., iglesia, e.g.a., hancock, l.e., harward, d.h., gilleskie, d., oneill, j., imperial, r., ko, z., benton, m.h., doan, m., bickford, k., detwiler, r., andreoni, k., mahan, j.d., smith, z., hooper, s., gibson, k.l.
#
# 11/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1007/s00194-021-00517-1
# title : on the occasion of the 100th birthday of otto prokop (19212009)
# authors : geserick, g., wirth, i.
#
# doi : 10.1007/s00194-021-00517-1
# title : on the occasion of the 100th birthday of otto prokop (1921-2009)
# authors : geserick, g, wirth, i
#
# 12/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.17059/2013-3-11
# title : development of protected area system of the komi republic
# authors : tikhonova, t.v.
#
# doi : None
# title : development of protected area system of the komi republic
# authors : tikhonova, tv
#
# 13/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.2165/11598920-000000000-00000
# title : using the economics of certification to improve the safety and quality of male circumcision in developing countries: three models of implementation
# authors : richards, m.r.
#
# doi : None
# title : using the economics of certification to improve the safety and quality of male circumcision in developing countries three models of implementation
# authors : richards, mr
#
# 14/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1016/j.orgdyn.2015.02.003
# title : the sustainable effectiveness model: moving corporations beyond the philanthropy paradigm.
# authors : None
#
# doi : 10.1016/j.orgdyn.2015.02.003
# title : the sustainable effectiveness model: moving corporations beyond the philanthropy paradigm
# authors : lawler, ee, conger, ja
#
# 15/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : sustainability reporting in the mining sector: identifying critical issues
# authors : viviers, s., boudler, j.-m.
#
# doi : None
# title : sustainability reporting in the mining sector: identifying critical issues
# authors : viviers, s, boudler, jm
#
# 16/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1139/z95-152
# title : use of space by the woolly opossum caluromys philander (marsupialia, didelphidae) in french guiana
# authors : julien-laferriere, d.
#
# doi : 10.1139/z95-152
# title : use of space by the woolly opossum caluromys philander (marsupialia, didelphidae) in french-guiana
# authors : julienlaferriere, d
#
# 17/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1016/j.surge.2021.11.001
# title : the role of registered charities in the delivery of global surgery in low- and middle-income countries - a personal experience
# authors : corbally, m.t.
#
# doi : 10.1016/j.surge.2021.11.001
# title : the role of registered charities in the delivery of global surgery in low- and middle-income countries-a personal experience
# authors : corbally, mt
#
# 18/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# doi : None
# title : corporate social responsibility and leadership
# authors : duns, s.
#
# 19/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.4087/foundationreview-d-10-00040
# title : developing foundation-university-grantee collaboratives as a model for high-impact philanthropy
# authors : nayfack, m.b., wohlstetter, p.
#
# doi : 10.4087/foundationreview-d-10-00040
# title : developing foundation-university-grantee collaboratives as a model for high-impact philanthropy results
# authors : nayfack, mb, wohlstetter, p
#
# 19/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : nela recognizes outstanding contributions
# authors : None
#
# doi : 10.1108/jpbafm-07-2020-0101
# title : nigerian budgetary response to the covid-19 pandemic and its shrinking fiscal space: financial sustainability, employment, social inequality and business implications
# authors : ejiogu, a, okechukwu, o, ejiogu, c
#
# 20/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1016/s2352-3026(21)00170-8
# title : dose-dense brentuximab vedotin plus ifosfamide, carboplatin, and etoposide for second-line treatment of relapsed or refractory classical hodgkin lymphoma: a single centre, phase 1/2 study
# authors : lynch, r.c., cassaday, r.d., smith, s.d., fromm, j.r., cowan, a.j., warren, e.h., shadman, m.s., shustov, a., till, b.g., ujjani, c.s., libby, e.n., iii, philip, m., coye, h., martino, c.n., bhark, s.l., morris, k., rasmussen, h., behnia, s., voutsinas, j., gopal, a.k.
#
# doi : None
# title : g8 focuses on clean energy and nuclear proliferation
# authors : None
#
# 20/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.22434/ifamr2015.0202
# title : glimpse 2.0: a framework to feed the world
# authors : connolly, a.j., sodreb, l.r., phillips-connolly, k.
#
# doi : 10.22434/ifamr2015.0202
# title : glimpse 2.0: a framework to feed the world research article
# authors : connolly, aj, sodre, lr, phillips-connolly, k
#
# 20/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1163/18765149-12341305
# title : mindfully sharing capital in modern china
# authors : lu, s., rios, j., huang, c.-c.
#
# doi : 10.1163/18765149-12341305
# title : mindfully sharing capital in modern china culture of giving and influence of chinese philosophy
# authors : lu, s, rios, j, huang, cc
#
# 21/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1080/21568316.2020.1850515
# title : corporate sustainability practices in tourismevidence from tanzania
# authors : suluo, s.j., mossberg, l., andersson, t.d., anderson, w., assad, m.j.
#
# doi : 10.1080/21568316.2020.1850515
# title : corporate sustainability practices in tourism-evidence from tanzania
# authors : suluo, sj, mossberg, l, andersson, td, anderson, w, assad, mj
#
# 22/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.4324/9780203051641
# title : with the best of intentions: singapore volunteers and donors and the tsunami reconstruction
# authors : tay, k.t., paige, j.t.
#
# doi : 10.1300/j198v05n03_06
# title : with the best of intentions: singapore volunteers and donors and the tsunami reconstruction
# authors : keong, t.t., johnson tan, p.
#
# 23/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1080/0267257x.2017.1323775
# title : the weight of the saddened soul: the bidirectionality between physical heaviness and sadness and its implications for sensory marketing
# authors : hung, y., zheng, x., carlson, j., giurge, l.m.
#
# doi : 10.1080/0267257x.2017.1323775
# title : the weight of the saddened soul: the bidirectionality between physical heaviness and sadness and its implications for sensory marketing
# authors : hung, yc, zheng, x, carlson, j, giurge, lm
#
# 23/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1080/10357823.2015.1084996
# title : the influence of elite philanthropy on ngo development in china
# authors : deng, g.
#
# doi : 10.1080/10357823.2015.1084996
# title : the influence of elite philanthropy on ngo development in china
# authors : deng, gs
#
# 24/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : corporate social responsibility for sustainable corporate image,and competitive performance of manufacturing firms in nigeria
# authors : olaoye, b.g., iyiola, o.o., moses, c.l.
#
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# 25/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1108/eb045802
# title : radiomarathon in the guinness world of records: a tool for building a strong corporate reputation through corporate social responsibility
# authors : papasolomou doukakis, i.
#
# doi : 10.1108/eb045802
# title : radiomarathon in the guinness world of records: a tool for building a strong corporate reputation through corporate social responsibility ioanna papasolomou doukakis, intercollege, cyprus
# authors : doukakis, ip
#
# 25/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1016/j.ejso.2019.04.005
# title : making an impact: a priority setting consultation exercise to improve outcomes in patients with locally advanced, recurrent and metastatic colorectal cancer
# authors : vallance, a.e., harji, d., fearnhead, n.s., acheson, a., adams, k., adams, r., alsina, d., antoniou, a., arnott, r., bach, s., battersby, n., bedford, m., beggs, a., belcher, e., boulstridge, l., boyle, k., bradbury, j., braun, m., brown, e., brown, g., burling, d., cameron, i., campbell, k., carney, k., cecil, t., chapman, m., chapman, s., chong, p., coyne, p., clark, s., crane, s., daniels, i., davies, j., davies, l., davies, m., dawson, c., dawson, p., duff, m., demick, a., elavia, k., gardner, r., evans, m., fenwick, s., galbraith, s., good, j., gilbert, d., griffiths, b., hargest, r., hill, j., hompes, r., huguet, e., jenkins, j., kapur, s., karandikar, s., katte, c., kumar, n., langman, g., lim, m., lopes de azevedo-gilbert, r., macdonald, a., machesney, m., mathur, p., maxwell-armstrong, c., mcarthur, d., mcdermott, f., mcdermott, u., mirnezami, a., mitchell, p., mohamed, f., moran, b., morris, m., murphy, j., nakas, a., norris, c., odwyer, s., panagiotopoulou, i., pellino, g., polignano, f., powell, c., renehan, a., rowbottom, p., sagar, p., samuel, l., seligmann, j., shaikh, i., simpson, a., skaife, p., skarrot, p., speake, w., stearns, a., stylianides, n.a., sutton, p., swarnkar, k., taylor, c., tebala, g., thorpe, g., tiernan, j., toogood, g., vimalchandran, d., walker, k., walsh, c., warren, o., wasan, h., welsh, f., wheeler, j., whitley, s., wilson, m., winter, d., youssef, h., impact collaborative
#
# doi : None
# title : the arctic scrolls
# authors : simpson, v.
#
# 25/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.18848/2325-1166/cgp/v10i3-4/55351
# title : sustainability in the travel industry: empirical findings from the biggest travel companies operating in finland
# authors : kotonen, u., savonen, t.
#
# doi : 10.1002/9781119199137.ch3
# title : sustainable investment strategies
# authors : None
#
# 25/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1002/9781119199137.ch3
# title : sustainable investment strategies
# authors : None
#
# doi : 10.1108/14720700510562730
# title : the measurement of responsible governance and management of npos in new zealand: an evaluation tool for npos, donors and government. if you have no money - you have no mission
# authors : mueller, j., williams, d., higgins, a., tou, m.
#
# 25/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1093/nar/gkt1250
# title : mvoc: a database of microbial volatiles
# authors : lemfack, mc, nickel, j, dunkel, m, preissner, r, piechulla, b
#
# doi : 10.1093/nar/gkx1016
# title : mvoc 2.0: a database of microbial volatiles
# authors : lemfack, mc, gohlke, bo, toguem, smt, preissner, s, piechulla, b, preissner, r
#
# 25/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.2752/175183412x13522006994773
# title : krishnas prasadam: eating our way back to godhead
# authors : king, a.s.
#
# doi : 10.2752/175183412x13522006994773
# title : anna s. king, krishnas prasadam: eating our way back to godhead
# authors : king, as
#
# 25/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : notables and ladies in nineteenth-century jewish philanthropy: case studies in france, italy and england
# authors : dancona, l.l.
#
# doi : None
# title : notables and ladies in nineteenth-century jewish philanthropy: case studies in france, italy and england
# authors : levi dancona, l
#
# 25/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.2752/175183412x13522006994773
# title : krishnas prasadam: eating our way back to godhead
# authors : king, a.s.
#
# doi : 10.2752/175183412x13522006994773
# title : anna s. king, krishnas prasadam: eating our way back to godhead
# authors : king, as
#
# 25/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# doi : None
# title : notables and ladies in nineteenth-century jewish philanthropy: case studies in france, italy and england
# authors : dancona, l.l.
#
# doi : None
# title : notables and ladies in nineteenth-century jewish philanthropy: case studies in france, italy and england
# authors : levi dancona, l
#
# 26/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : None
# title : social business
# authors : loffler, m.
#
# doi : 10.1016/j.ecolind.2016.07.007
# title : social sustainability in the supply chain: construct development and measurement validation
# authors : mani, v, agarwal, r, gunasekaran, a, papadopoulos, t, dubey, r, childe, sj
#
# 27/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# doi : 10.1080/1331677x.2022.2046480
# title : impact of corporate social responsibility on social and economic sustainability
# authors : duc tai, t.
#
# doi : None
# title : corporate social responsibility
# authors : rudakova, e.n., pashentsev, d.a., myrzalimov, r.m., alpatov, y.m., baranov, v.a.
#
# 27/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# Finished labeling
# Clustering...
# # duplicate sets 2443
# deduped from (3530, 31) to (2443, 31)

# %% [markdown]
# # Experiments

# %%
# naive dedupe
# filepath = '../asreview/input/220420.ris'
# df = dedupe(filepath)

# https://stackoverflow.com/questions/26033301/make-pandas-dataframe-to-a-dict-and-dropna
# a=[ v.dropna().to_dict() for k,v in dfd.iterrows() ]
# write_ris(a,'test.ris')

# %%
# files = ['1-20scopus.ris', '1-20savedrecs.ris']
# filepath = '../data/220420'

# dfs = []
# for file in files:
#     risfile = read_ris(f'{filepath}/{file}')
#     dfs += [pd.DataFrame.from_dict(risfile)]
# df = pd.concat(dfs,ignore_index=True)
# def same_title(t1, t2):
#     return fuzz.ratio(t1['title'].lower(), t2['title'].lower()) > 75
    
# df['real_id'] = find_partitions(
#     df=df,
#     match_func=same_title
# )

# df[df.duplicated(subset='real_id')]
